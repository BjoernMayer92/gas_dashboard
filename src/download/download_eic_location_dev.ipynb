# %% [markdown]
# # 0 Import Packages

# %%
import sys
import os
import json
from pathlib import Path
import pandas as pd

# %% [markdown]
# # 1 Metadata

# %% [markdown]
# ## 1.1 Custom Packages

# %%
root_dir = Path.cwd().parents[1]
conf_dir = os.path.join(root_dir,"config")


sys.path.append(str(conf_dir))

import config
import keys

extraction_keyword_list = config.AGSI_EXTRACTION_KEYWORD_LIST
metadata_keyword_list = config.AGSI_METADATA_KEYWORD_LIST
api_string = config.AGSI_API_STRING
sys.path.append(str(config.SRC_DIR))

import agsi_api as agsi

# %% [markdown]
# # 3 Load Data

# %%
file_facility_queries = os.path.join(config.DATA_AGSI_DIR,"Query_listing.json")

# %%
data = pd.read_json(file_facility_queries)

# %%
location_name_list = []
location_coordinates_list = []

for name in data["name"]:    
    query_string_parameter_dict = {"input":name, "key":keys.GOOGLE}

    query_string = agsi.generate_query_string(config.GOOGLE_API_STRING, query_string_parameter_dict = query_string_parameter_dict)

    resp = requests.get(query_string)
    resp_json = resp.json()

    status = resp_json["status"]
    if status=="OK":
        location_coordinates  = resp_json["results"][0]["geometry"]["location"]
        location_name = resp_json["results"][0]["name"]
    else: 
        location_name  = "NA"
        location_coordinates = "NA"

    location_name_list.append(location_name)
    location_coordinates_list.append(location_coordinates)

# %%
data["location_name"] = location_name_list
data["location_coordinates"] = location_coordinates_list

# %%
data
# Out:
#    country           company          facility  \
# 0       DE  21X000000001160J  21Z000000000271O
# 1       DE  21X000000001160J  21W0000000001148
# 2       DE  21X000000001160J  21W0000000001261
# 3       DE  37X0000000000151  21W0000000000184
# 4       DE  37X0000000000224  21W0000000001083
# 5       DE  37X000000000152S  37W000000000003M
# 6       DE  11X0-0000-0667-8  11W0-0000-0432-M
# 7       DE  21X0000000010849  21W000000000012G
# 8       DE  21X000000001368W  21W000000000100J
# 9       DE  21X000000001297T  21W0000000000281
# 10      DE  21X000000001080H  21Z000000000291I
# 11      DE  21X0000000011756  21W0000000001075
# 12      DE  21X0000000011756  21W000000000048W
# 13      DE  21X0000000011756  21W000000000104B
# 14      DE  21X0000000011756  21W000000000103D
# 15      DE  21X0000000011756  21W0000000001067
# 16      DE  21X0000000011756  21W0000000000508
# 17      DE  21X0000000011756  PRIOR_EWE_000001
# 18      DE  21X0000000011756  37W000000000002O
# 19      DE  21X0000000013805  21W000000000020H
# 20      DE  21X000000001140P  21W000000000097J
# 21      DE  37X000000000047P  21W000000000055Z
# 22      DE  37X000000000047P  21W0000000000540
# 23      DE  37X000000000042Z  21W000000000064Y
# 24      DE  37X000000000042Z  21W0000000000621
# 25      DE  37X000000000042Z  37Y000000000386Q
# 26      DE  21X0000000011748  21W0000000000192
# 27      DE  37X0000000000119  21W000000000005D
# 28      DE  25X-OMVGASSTORA5  21W000000000056X
# 29      DE  21X000000001262B  21W0000000000532
# 30      DE  21X000000001262B  21W0000000000524
# 31      DE  21X000000001262B  21W000000000004F
# 32      DE  21X000000001262B  21W0000000000516
# 33      DE  21X000000001262B  21W0000000000265
# 34      DE  21X000000001262B  21W000000000003H
# 35      DE  21X000000001262B  21W000000000121B
# 36      DE  21X000000001072G  21W000000000093R
# 37      DE  21X000000001072G  21W000000000092T
# 38      DE  21X000000001072G  21W0000000000273
# 39      DE  21X000000001072G  21W000000000091V
# 40      DE  21X000000001072G  21W000000000090X
# 41      DE  21X000000001072G  21W000000000089I
# 42      DE  37X000000000051Y  21W000000000058T
# 43      DE  37X000000000051Y  21W0000000001164
# 44      DE  21X000000001307F  21W000000000030E
# 45      DE  21X000000001310Q  21W000000000085Q
# 46      DE  21X000000001127H  21W000000000067S
# 47      DE  21X000000001127H  21W000000000066U
# 48      DE  21X000000001127H  21W000000000065W
# 49      DE  21X000000001127H  21W0000000000613
# 50      DE  21X000000001127H  21W0000000000605
# 51      DE  21X000000001127H  21W000000000059R
# 52      DE  21X000000001127H  21W0000000000168
# 53      DE  21X000000001127H  21W000000000083U
# 54      DE  21X000000001138C  21W000000000120D
# 55      DE  21X000000001138C  21W0000000001091
# 56      DE  21X000000001138C  21W0000000000427
# 57      DE  21X000000001138C  21W000000000023B
# 58      DE  21X000000001138C  21W000000000128Y
#
#                                                  name  \
# 0                                          UGS Rehden
# 1                               UGS Jemgum H (astora)
# 2                           VSP NORD (Rehden, Jemgum)
# 3                                     UGS Wolfersberg
# 4                                          UGS Berlin
# 5                                 VGS UGS Etzel (EDF)
# 6                                VGS UGS Etzel (EnBW)
# 7                          UGS Enschede - Epe (Eneco)
# 8         UGS Etzel EGL (Equinor Storage Deutschland)
# 9                                       UGS Katharina
# 10                                      UGS Etzel EKB
# 11                                     UGS EWE-Zone L
# 12                                   UGS Rüdersdorf H
# 13                                 UGS Nüttermoor H-2
# 14                                 UGS Nüttermoor H-3
# 15                               UGS Nüttermoor L GUD
# 16                                 UGS Jemgum H (EWE)
# 17  UGS Nüttermoor H aggregated data prior to 7 Ap...
# 18                                     EWE H-Gas Zone
# 19                                          UGS Kraak
# 20                                      UGS Epe (KGE)
# 21                                UGS Etzel ESE (MET)
# 22                                        UGS Reckrod
# 23  UGS Haehnlein (historical data prior to 01/04/...
# 24  UGS Stockstadt (historical data prior to 01/04...
# 25  VGS Zone MND ESG (UGS Stockstadt + UGS Haehnlein)
# 26                                  UGS Inzenham-West
# 27                          UGS Enschede - Epe (Nuon)
# 28                                UGS Etzel ESE (OMV)
# 29                                   UGS Epe-L-RWEGSW
# 30  UGS Epe-H-RWEGSWEST (historical data prior to ...
# 31                                UGS KALLE-RWEGSWEST
# 32  UGS Xanten-RWEGSWEST (historical data prior to...
# 33                            UGS STASSFURT-RWEGSWEST
# 34                               UGS Epe-NL-RWEGSWEST
# 35                                   INNEXPOOL-RWEGSW
# 36                                         UGS Uelsen
# 37                                      UGS Harsefeld
# 38                                      UGS Peckensen
# 39                                      UGS Fronhofen
# 40                                          UGS Lesum
# 41                                   UGS Schmidhausen
# 42  UGS Kiel Rönne (historical data Hansewerk prio...
# 43                                     UGS Kiel-Rönne
# 44                                   UGS Allmenhausen
# 45                                    UGS Epe Trianel
# 46                                      UGS Krummhorn
# 47                               UGS Epe Uniper H-Gas
# 48                               UGS Epe Uniper L-Gas
# 49                                       UGS Bierwang
# 50                                     UGS Breitbrunn
# 51                         UGS Etzel Erdgas Lager EGL
# 52              UGS Etzel ESE (Uniper Energy Storage)
# 53                                   UGS Eschenfelden
# 54                                UGS Etzel ESE (VGS)
# 55                                VGS VTP Storage GPL
# 56         VGS Storage Hub (Bernburg, Bad Lauchstädt)
# 57  UGS Kirchheiligen (historical data prior to 31...
# 58                                 UGS Jemgum H (VGS)
#
#                                          query_string  \
# 0   https://agsi.gie.eu/api?&company=21X0000000011...
# 1   https://agsi.gie.eu/api?&company=21X0000000011...
# 2   https://agsi.gie.eu/api?&company=21X0000000011...
# 3   https://agsi.gie.eu/api?&company=37X0000000000...
# 4   https://agsi.gie.eu/api?&company=37X0000000000...
# 5   https://agsi.gie.eu/api?&company=37X0000000001...
# 6   https://agsi.gie.eu/api?&company=11X0-0000-066...
# 7   https://agsi.gie.eu/api?&company=21X0000000010...
# 8   https://agsi.gie.eu/api?&company=21X0000000013...
# 9   https://agsi.gie.eu/api?&company=21X0000000012...
# 10  https://agsi.gie.eu/api?&company=21X0000000010...
# 11  https://agsi.gie.eu/api?&company=21X0000000011...
# 12  https://agsi.gie.eu/api?&company=21X0000000011...
# 13  https://agsi.gie.eu/api?&company=21X0000000011...
# 14  https://agsi.gie.eu/api?&company=21X0000000011...
# 15  https://agsi.gie.eu/api?&company=21X0000000011...
# 16  https://agsi.gie.eu/api?&company=21X0000000011...
# 17  https://agsi.gie.eu/api?&company=21X0000000011...
# 18  https://agsi.gie.eu/api?&company=21X0000000011...
# 19  https://agsi.gie.eu/api?&company=21X0000000013...
# 20  https://agsi.gie.eu/api?&company=21X0000000011...
# 21  https://agsi.gie.eu/api?&company=37X0000000000...
# 22  https://agsi.gie.eu/api?&company=37X0000000000...
# 23  https://agsi.gie.eu/api?&company=37X0000000000...
# 24  https://agsi.gie.eu/api?&company=37X0000000000...
# 25  https://agsi.gie.eu/api?&company=37X0000000000...
# 26  https://agsi.gie.eu/api?&company=21X0000000011...
# 27  https://agsi.gie.eu/api?&company=37X0000000000...
# 28  https://agsi.gie.eu/api?&company=25X-OMVGASSTO...
# 29  https://agsi.gie.eu/api?&company=21X0000000012...
# 30  https://agsi.gie.eu/api?&company=21X0000000012...
# 31  https://agsi.gie.eu/api?&company=21X0000000012...
# 32  https://agsi.gie.eu/api?&company=21X0000000012...
# 33  https://agsi.gie.eu/api?&company=21X0000000012...
# 34  https://agsi.gie.eu/api?&company=21X0000000012...
# 35  https://agsi.gie.eu/api?&company=21X0000000012...
# 36  https://agsi.gie.eu/api?&company=21X0000000010...
# 37  https://agsi.gie.eu/api?&company=21X0000000010...
# 38  https://agsi.gie.eu/api?&company=21X0000000010...
# 39  https://agsi.gie.eu/api?&company=21X0000000010...
# 40  https://agsi.gie.eu/api?&company=21X0000000010...
# 41  https://agsi.gie.eu/api?&company=21X0000000010...
# 42  https://agsi.gie.eu/api?&company=37X0000000000...
# 43  https://agsi.gie.eu/api?&company=37X0000000000...
# 44  https://agsi.gie.eu/api?&company=21X0000000013...
# 45  https://agsi.gie.eu/api?&company=21X0000000013...
# 46  https://agsi.gie.eu/api?&company=21X0000000011...
# 47  https://agsi.gie.eu/api?&company=21X0000000011...
# 48  https://agsi.gie.eu/api?&company=21X0000000011...
# 49  https://agsi.gie.eu/api?&company=21X0000000011...
# 50  https://agsi.gie.eu/api?&company=21X0000000011...
# 51  https://agsi.gie.eu/api?&company=21X0000000011...
# 52  https://agsi.gie.eu/api?&company=21X0000000011...
# 53  https://agsi.gie.eu/api?&company=21X0000000011...
# 54  https://agsi.gie.eu/api?&company=21X0000000011...
# 55  https://agsi.gie.eu/api?&company=21X0000000011...
# 56  https://agsi.gie.eu/api?&company=21X0000000011...
# 57  https://agsi.gie.eu/api?&company=21X0000000011...
# 58  https://agsi.gie.eu/api?&company=21X0000000011...
#
#                                         location_name  \
# 0               GASCADE GmbH Verdichterstation Rehden
# 1                 Erdgasspeicher Jemgum (Gas Storage)
# 2                 Erdgasspeicher Jemgum (Gas Storage)
# 3                                      bayernugs GmbH
# 4   Untergrundspeicher- u. Geotechnologie Systeme ...
# 5                            EDF Gas Deutschland GmbH
# 6                                             EnBW AG
# 7   Eneco Gasspeicher B.V. - Eneco Gasspeicher, Zw...
# 8                    Equinor Deutschland Storage GmbH
# 9                                       UGS Katharina
# 10   Etzel- Kavernenbetriebsgesellschaft mbH & Co. KG
# 11                               EWE Gasspeicher GmbH
# 12                      EWE Erdgasspeicher Rüdersdorf
# 13                                                 NA
# 14                                                 NA
# 15                                                 NA
# 16                Erdgasspeicher Jemgum (Gas Storage)
# 17                                                 NA
# 18                               EWE Gasspeicher GmbH
# 19                                       Hansewerk Ag
# 20  KGBE - Kommunale Gasspeicher Beteiligungsgesel...
# 21                                  Storag Etzel GmbH
# 22                                   UGS Allmenhausen
# 23                                                 NA
# 24                                                 NA
# 25                       MND Gas Storage Germany GmbH
# 26                                     NAFTA Speicher
# 27                          Nuon Epe Gasspeicher GmbH
# 28                                                 NA
# 29       RWE Gas Storage West GmbH, Gasspeicher Epe-L
# 30                                                 NA
# 31                         RWE Gas Storage CZ, s.r.o.
# 32                                                 NA
# 33    RWE Gas Storage West GmbH, Gasspeicher Staßfurt
# 34                         Uniper Energy Storage GmbH
# 35                         RWE Gas Storage CZ, s.r.o.
# 36  Erdgasspeicher Uelsen, Storengy Deutschland Be...
# 37  Erdgasspeicher Harsefeld, Storengy Deutschland...
# 38  Erdgasspeicher Peckensen, Storengy Deutschland...
# 39  Erdgasspeicher Fronhofen, Storengy Deutschland...
# 40  Erdgasspeicher Lesum, Storengy Deutschland Bet...
# 41  Erdgasspeicher Schmidhausen, Storengy Deutschl...
# 42                                                 NA
# 43                                   SWKiel Netz GmbH
# 44                                   UGS Allmenhausen
# 45                          Nuon Epe Gasspeicher GmbH
# 46                               KiK Krummhörn Pewsum
# 47                         Uniper Energy Storage GmbH
# 48                         Uniper Energy Storage GmbH
# 49  Untergrundspeicher- u. Geotechnologie Systeme ...
# 50                   Freiwillige Feuerwehr Breitbrunn
# 51    ETZEL-KAVERNENBETRIEBSGESELLSCHAFT MBH & CO. KG
# 52                           Uniper Energy Sales GmbH
# 53                                       Eschenfelden
# 54                                  Storag Etzel GmbH
# 55                               VNG Gasspeicher GmbH
# 56  Untergrundgasspeicher Bernburg, VNG Gasspeiche...
# 57                                                 NA
# 58                Erdgasspeicher Jemgum (Gas Storage)
#
#                                  location_coordinates
# 0               {'lat': 52.6196289, 'lng': 8.4960442}
# 1        {'lat': 53.25334429999999, 'lng': 7.3885866}
# 2        {'lat': 53.25334429999999, 'lng': 7.3885866}
# 3              {'lat': 48.1253975, 'lng': 11.5348298}
# 4              {'lat': 52.2701376, 'lng': 13.5350098}
# 5                {'lat': 53.456193, 'lng': 7.8389024}
# 6               {'lat': 53.548289, 'lng': 10.0017138}
# 7               {'lat': 52.1801465, 'lng': 6.9759321}
# 8       {'lat': 53.4526394, 'lng': 7.895024999999999}
# 9        {'lat': 51.75060250000001, 'lng': 11.739032}
# 10      {'lat': 53.0897705, 'lng': 8.775602899999999}
# 11              {'lat': 53.1405965, 'lng': 8.1952319}
# 12             {'lat': 52.4726147, 'lng': 13.8055207}
# 13                                                 NA
# 14                                                 NA
# 15                                                 NA
# 16       {'lat': 53.25334429999999, 'lng': 7.3885866}
# 17                                                 NA
# 18              {'lat': 53.1405965, 'lng': 8.1952319}
# 19             {'lat': 53.4183422, 'lng': 11.3757218}
# 20              {'lat': 52.2108423, 'lng': 7.0282836}
# 21              {'lat': 53.4534516, 'lng': 7.9031959}
# 22             {'lat': 51.2189584, 'lng': 10.7102792}
# 23                                                 NA
# 24                                                 NA
# 25                   {'lat': 49.7425, 'lng': 8.60184}
# 26             {'lat': 47.8874937, 'lng': 12.1035513}
# 27              {'lat': 52.1786477, 'lng': 6.9925277}
# 28                                                 NA
# 29              {'lat': 52.1765718, 'lng': 7.0075055}
# 30                                                 NA
# 31             {'lat': 49.7150439, 'lng': 18.5321642}
# 32                                                 NA
# 33                 {'lat': 51.89348, 'lng': 11.55384}
# 34       {'lat': 52.16094409999999, 'lng': 7.0033914}
# 35             {'lat': 49.7150439, 'lng': 18.5321642}
# 36      {'lat': 52.5050292, 'lng': 6.825758899999999}
# 37              {'lat': 53.4364392, 'lng': 9.4814163}
# 38      {'lat': 52.80145779999999, 'lng': 10.9400408}
# 39      {'lat': 47.8519713, 'lng': 9.415369499999999}
# 40              {'lat': 53.1604568, 'lng': 8.7179833}
# 41             {'lat': 47.9152187, 'lng': 12.0391472}
# 42                                                 NA
# 43             {'lat': 54.3093011, 'lng': 10.0963267}
# 44             {'lat': 51.2189584, 'lng': 10.7102792}
# 45              {'lat': 52.1786477, 'lng': 6.9925277}
# 46               {'lat': 53.427699, 'lng': 7.1065879}
# 47      {'lat': 51.2135133, 'lng': 6.748565399999999}
# 48       {'lat': 52.16094409999999, 'lng': 7.0033914}
# 49             {'lat': 52.2701376, 'lng': 13.5350098}
# 50              {'lat': 48.035108, 'lng': 11.1349736}
# 51      {'lat': 53.4524987, 'lng': 7.907863600000001}
# 52  {'lat': 53.56268679999999, 'lng': 9.9309324999...
# 53             {'lat': 49.5804599, 'lng': 11.6147504}
# 54              {'lat': 53.4534516, 'lng': 7.9031959}
# 55             {'lat': 51.3640762, 'lng': 12.3995891}
# 56             {'lat': 51.7481803, 'lng': 11.7441387}
# 57                                                 NA
# 58       {'lat': 53.25334429999999, 'lng': 7.3885866}
